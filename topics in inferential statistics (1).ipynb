# %% [markdown]
# # <center> Inferential Statistics</center>
# ## <center>topics in inferential statistics:</center>
# ##### -Sampling Techniques</center>
# ##### -Estimation</center>
# ##### -Hypothesis Testing</center>
# ##### -Confidence Intervals</center>
# ##### -Regression Analysis</center>
# ##### -ANOVA (Analysis of Variance)</center>
# ##### -Nonparametric Methods</center>
# ##### -Probability Distributions</center>
# ##### -Sampling Distributions</center>
# ##### -Type I and Type II Errors</center>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read DataSet and Creat DataFram

# %%
df=pd.read_csv('Data Science Jobs Salaries.csv')
x=pd.DataFrame(df)
print(x)
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Information about DataSet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        243 non-null    float64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 21.2+ KB

# %% [markdown]
# # Head
# #### mean top 5 rows

# %%
df.head()
# Out:
#   work_year experience_level employment_type                  job_title  \
# 0     2021e               EN              FT    Data Science Consultant
# 1      2020               SE              FT             Data Scientist
# 2     2021e               EX              FT       Head of Data Science
# 3     2021e               EX              FT               Head of Data
# 4     2021e               EN              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   54000             EUR          64369                 DE          50.0
# 1   60000             EUR          68428                 GR         100.0
# 2   85000             USD          85000                 RU           0.0
# 3  230000             USD         230000                 RU          50.0
# 4  125000             USD         125000                 US         100.0
#
#   company_location company_size
# 0               DE            L
# ...

# %% [markdown]
# # Tail
# #### 5 rows from bottom

# %%
df.tail()
# Out:
#     work_year experience_level employment_type                 job_title  \
# 240      2020               SE              FT            Data Scientist
# 241     2021e               MI              FT  Principal Data Scientist
# 242      2020               EN              FT            Data Scientist
# 243      2020               EN              CT     Business Data Analyst
# 244     2021e               SE              FT      Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 240   412000             USD         412000                 US         100.0
# 241   151000             USD         151000                 US         100.0
# 242   105000             USD         105000                 US         100.0
# 243   100000             USD         100000                 US         100.0
# 244  7000000             INR          94917                 IN          50.0
#
#     company_location company_size
# ...

# %% [markdown]
# # Full Information About DataSet

# %%
df.describe()
# Out:
#              salary  salary_in_usd  remote_ratio
# count  2.450000e+02     245.000000    243.000000
# mean   5.025418e+05   99868.012245     69.753086
# std    2.276230e+06   83983.326949     37.216431
# min    4.000000e+03    2876.000000      0.000000
# 25%    6.000000e+04   45896.000000     50.000000
# 50%    1.030000e+05   81000.000000    100.000000
# 75%    1.740000e+05  130000.000000    100.000000
# max    3.040000e+07  600000.000000    100.000000

# %% [markdown]
# # Printing spacific rows

# %%
df['salary']
# Out:
# 0        54000
# 1        60000
# 2        85000
# 3       230000
# 4       125000
#         ...
# 240     412000
# 241     151000
# 242     105000
# 243     100000
# 244    7000000
# Name: salary, Length: 245, dtype: int64

# %% [markdown]
# # Finding Null Values

# %%
df.isnull()
# Out:
#      work_year  experience_level  employment_type  job_title  salary  \
# 0        False             False            False      False   False
# 1        False             False            False      False   False
# 2        False             False            False      False   False
# 3        False             False            False      False   False
# 4        False             False            False      False   False
# ..         ...               ...              ...        ...     ...
# 240      False             False            False      False   False
# 241      False             False            False      False   False
# 242      False             False            False      False   False
# 243      False             False            False      False   False
# 244      False             False            False      False   False
#
#      salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Filling Missing Values

# %%
df.fillna('NaN')
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# ...

# %% [markdown]
# # Finding missing Values

# %%
df.notnull()
# Out:
#      work_year  experience_level  employment_type  job_title  salary  \
# 0         True              True             True       True    True
# 1         True              True             True       True    True
# 2         True              True             True       True    True
# 3         True              True             True       True    True
# 4         True              True             True       True    True
# ..         ...               ...              ...        ...     ...
# 240       True              True             True       True    True
# 241       True              True             True       True    True
# 242       True              True             True       True    True
# 243       True              True             True       True    True
# 244       True              True             True       True    True
#
#      salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Dropping Missing values

# %%
df.dropna()
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Plotting

# %%
df.plot()
# Out:
# <Axes: >
